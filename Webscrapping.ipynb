# %%
import requests
import bs4

# %%
res=requests.get('https://yahoo.co.in/')

# %%
type(res)
# Out:
# requests.models.Response

# %%
n0=res.text
n0
# Out:
# '<!DOCTYPE html>\n<html id="atomic" lang="en-IN" class="atomic   l-out Pos-r https fp fp-v2 rc1 fp-default mini-uh-on uh-topbar-on viewer-right two-col ntk-wide ltr desktop Desktop bkt704">\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    \n    <title>Yahoo India | News, Finance, Cricket, Lifestyle and Entertainment</title><meta http-equiv="x-dns-prefetch-control" content="on"><link rel="dns-prefetch" href="//s.yimg.com"><link rel="preconnect" href="//s.yimg.com"><link rel="dns-prefetch" href="//csc.beap.bc.yahoo.com"><link rel="preconnect" href="//csc.beap.bc.yahoo.com"><link rel="dns-prefetch" href="//geo.yahoo.com"><link rel="preconnect" href="//geo.yahoo.com"><link rel="dns-prefetch" href="//comet.yahoo.com"><link rel="preconnect" href="//comet.yahoo.com"><link rel="dns-prefetch" href="//video-api.yql.yahoo.com"><link rel="preconnect" href="//video-api.yql.yahoo.com">    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n    \n    <meta na
# ...

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
n1=soup.select('title')

# %%
print(n1)
n1[0].getText()
# Out:
# [<title>Yahoo India | News, Finance, Cricket, Lifestyle and Entertainment</title>]
# 'Yahoo India | News, Finance, Cricket, Lifestyle and Entertainment'

# %%
n2=soup.select('div')

# %%
for i in n2:
    print(i.text)
# Out:
#
# SearchSkip to navigationSkip to main contentSkip to related contentSign inMailSign in to view your emailsMail()CoronavirusCricketNewsFinanceLifestyleMoviesWomenMore...
#
# SearchSkip to navigationSkip to main contentSkip to related contentSign inMailSign in to view your emailsMail()CoronavirusCricketNewsFinanceLifestyleMoviesWomenMore...
# SearchSkip to navigationSkip to main contentSkip to related contentSign inMailSign in to view your emailsMail()CoronavirusCricketNewsFinanceLifestyleMoviesWomenMore...
# SearchSkip to navigationSkip to main contentSkip to related contentSign inMailSign in to view your emailsMail()CoronavirusCricketNewsFinanceLifestyleMoviesWomenMore...
# SearchSkip to navigationSkip to main contentSkip to related contentSign inMailSign in to view your emails
# Search
# Search
#
# Sign inMailSign in to view your emails
#
# Sign in to view your emails
#
#
#
#
#
#
#
#
# Mail()CoronavirusCricketNewsFinanceLifestyleMoviesWomenMore...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
n3=soup.find_all('a',href=True)
for link in n3:
    print(link['href'])
# Out:
# https://in.yahoo.com/
# #header-nav-bar
# #Main
# #Aside
# https://login.yahoo.com/?.src=fpctx&.intl=in&.lang=en-IN&.done=https://in.yahoo.com&pspid=97684142
# https://mail.yahoo.com/?.intl=in&.lang=en-IN&.partner=none&.src=fp&activity=uh-mail&pspid=97684142
# https://login.yahoo.com/?.src=fpctx&.intl=in&.lang=en-IN&.done=https://in.yahoo.com&pspid=97684142
# https://ad.doubleclick.net/ddm/trackclk/N360801.1913355YAHOOADMANAGER/B23700935.274829057;dc_trk_aid=469369516;dc_trk_cid=129663027;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=
# https://mail.yahoo.com/?.intl=in&.lang=en-IN&.partner=none&.src=fp
# https://in.yahoo.com/topics/coronavirus-updates/
# https://cricket.yahoo.com/
# https://in.news.yahoo.com/
# https://in.finance.yahoo.com/
# https://in.style.yahoo.com/
# https://in.style.yahoo.com/tagged/movies
# https://in.makers.yahoo.com/
# https://in.yahoo.com/everything/
# https://cricket.yahoo.net/series/indian-premier-league-2020-1667/fixtures-results
# ...
